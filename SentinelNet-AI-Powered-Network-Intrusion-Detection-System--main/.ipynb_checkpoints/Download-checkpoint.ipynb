# %%
import os
import requests
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
DATA_DIR = "data"

if not os.path.exists(DATA_DIR):
    os.makedirs(DATA_DIR)

print(" Data folder ready!")
# Out:
#  Data folder ready!

# %%
URLS = {
    "KDDTrain+.txt": "https://raw.githubusercontent.com/defcom17/NSL_KDD/master/KDDTrain+.txt",
    "KDDTest+.txt": "https://raw.githubusercontent.com/defcom17/NSL_KDD/master/KDDTest+.txt"
}

# %%
def download_file(url, filename):
    local_path = os.path.join(DATA_DIR, filename)

    if os.path.exists(local_path):
        print(f"File already exists: {filename}")
        return

    print(f"Downloading {filename}...")

    response = requests.get(url, stream=True)
    response.raise_for_status()

    with open(local_path, "wb") as f:
        for chunk in response.iter_content(chunk_size=8000):
            f.write(chunk)

    print(f" Saved successfully: {local_path}")

# %%
for filename, url in URLS.items():
    download_file(url, filename)

print("\n Dataset Ready inside 'data/' folder")
# Out:
# File already exists: KDDTrain+.txt
# File already exists: KDDTest+.txt
#
#  Dataset Ready inside 'data/' folder

# %%
COLUMNS = [
    "duration", "protocol_type", "service", "flag", "src_bytes", "dst_bytes",
    "land", "wrong_fragment", "urgent", "hot", "num_failed_logins",
    "logged_in", "num_compromised", "root_shell", "su_attempted", "num_root",
    "num_file_creations", "num_shells", "num_access_files", "num_outbound_cmds",
    "is_host_login", "is_guest_login", "count", "srv_count", "serror_rate",
    "srv_serror_rate", "rerror_rate", "srv_rerror_rate", "same_srv_rate",
    "diff_srv_rate", "srv_diff_host_rate", "dst_host_count",
    "dst_host_srv_count", "dst_host_same_srv_rate", "dst_host_diff_srv_rate",
    "dst_host_same_src_port_rate", "dst_host_srv_diff_host_rate",
    "dst_host_serror_rate", "dst_host_srv_serror_rate", "dst_host_rerror_rate",
    "dst_host_srv_rerror_rate", "class", "difficulty_level"
]

# %%
train_path = os.path.join(DATA_DIR, "KDDTrain+.txt")
test_path  = os.path.join(DATA_DIR, "KDDTest+.txt")

train_df = pd.read_csv(train_path, names=COLUMNS)
test_df  = pd.read_csv(test_path, names=COLUMNS)

print(" Data Loaded Successfully!")
# Out:
#  Data Loaded Successfully!

# %%
train_df.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# ...

# %%
def dataset_summary(df, name="Dataset"):
    print("\n==============================")
    print(f"Summary of {name}")
    print("==============================")
    print("Shape:", df.shape)
    print("Missing Values:", df.isnull().sum().sum())
    print("Duplicate Rows:", df.duplicated().sum())
    print("Unique Attack Labels:", df["class"].nunique())
    print("==============================")

# %%
dataset_summary(train_df, "Training Data")
dataset_summary(test_df, "Testing Data")
# Out:
# ...
# Summary of Training Data
# ...
# Shape: (125973, 43)
# Missing Values: 0
# Duplicate Rows: 0
# Unique Attack Labels: 23
# ...
#
# ...
# Summary of Testing Data
# ...
# Shape: (22544, 43)
# Missing Values: 0
# Duplicate Rows: 0
# Unique Attack Labels: 38
# ...

# %%
train_df["class"].value_counts()
# Out:
# class
# normal             67343
# neptune            41214
# satan               3633
# ipsweep             3599
# portsweep           2931
# smurf               2646
# nmap                1493
# back                 956
# teardrop             892
# warezclient          890
# pod                  201
# guess_passwd          53
# buffer_overflow       30
# warezmaster           20
# land                  18
# imap                  11
# rootkit               10
# loadmodule             9
# ftp_write              8
# multihop               7
# phf                    4
# perl                   3
# spy                    2
# Name: count, dtype: int64

# %%
train_df.drop(columns=["num_outbound_cmds"], inplace=True)
test_df.drop(columns=["num_outbound_cmds"], inplace=True)

print(" Removed useless column: num_outbound_cmds")
# Out:
#  Removed useless column: num_outbound_cmds

# %%
train_df.to_csv("NSL_KDD_Train_Clean.csv", index=False)
test_df.to_csv("NSL_KDD_Test_Clean.csv", index=False)

print(" Clean CSV Files Saved Successfully!")
# Out:
#  Clean CSV Files Saved Successfully!

# %%
protocol_counts = train_df["protocol_type"].value_counts()

plt.figure(figsize=(8,4))
plt.bar(protocol_counts.index, protocol_counts.values)

plt.title("Traffic Volume by Protocol Type")
plt.xlabel("Protocol Type")
plt.ylabel("Count")

plt.show()

# %%
small_bytes = train_df[train_df["src_bytes"] < 6000]

plt.figure(figsize=(8,4))
sns.histplot(small_bytes["src_bytes"], bins=50, kde=True)

plt.title("Distribution of Source Bytes (<6000)")
plt.xlabel("Source Bytes")
plt.ylabel("Frequency")

plt.show()

# %%
small_bytes = train_df[train_df["src_bytes"] < 100000]

plt.figure(figsize=(8,4))
sns.boxplot(x="protocol_type", y="src_bytes", data=small_bytes)

plt.title("Source Byte Outliers by Protocol Type")
plt.xlabel("Protocol Type")
plt.ylabel("Source Bytes")

plt.show()

# %%
ct = pd.crosstab(train_df["protocol_type"], train_df["flag"])

plt.figure(figsize=(12,5))
sns.heatmap(ct, annot=True, fmt="d", cmap="Blues")

plt.title("Protocol Type vs Connection Flag")
plt.xlabel("Flag")
plt.ylabel("Protocol Type")

plt.show()

# %%
train_df["log_src_bytes"] = np.log1p(train_df["src_bytes"])

plt.figure(figsize=(10,4))
sns.histplot(train_df["log_src_bytes"], bins=50, kde=True)

plt.title("Log Distribution of Source Bytes")
plt.xlabel("log(1 + src_bytes)")
plt.ylabel("Frequency")

plt.show()

# %%
numerical_cols = ["duration", "src_bytes", "dst_bytes", "count", "srv_count"]

corr = train_df[numerical_cols].corr()

print("\nCorrelation Matrix:\n")
print(corr)
# Out:
# Correlation Matrix:
#
#            duration  src_bytes  dst_bytes     count  srv_count
# duration   1.000000   0.070737   0.034878 -0.079042  -0.039470
# src_bytes  0.070737   1.000000   0.000204 -0.005152  -0.002792
# dst_bytes  0.034878   0.000204   1.000000 -0.003543  -0.001754
# count     -0.079042  -0.005152  -0.003543  1.000000   0.471079
# srv_count -0.039470  -0.002792  -0.001754  0.471079   1.000000

# %%
top_attacks = train_df["class"].value_counts().index[1:4]

fig, axes = plt.subplots(1, 3, figsize=(12,5))

for i, attack in enumerate(top_attacks):
    sns.countplot(x="protocol_type", data=train_df[train_df["class"] == attack], ax=axes[i])
    axes[i].set_title(f"{attack} Attack Protocols")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x="class", y="duration", data=train_df)

plt.title("Duration Distribution Across Attack Classes")
plt.xticks(rotation=90)

plt.show()

# %%
avg_duration = train_df.groupby("class")["duration"].mean().sort_values(ascending=False)

plt.figure(figsize=(12,6))
avg_duration.plot(kind="bar")

plt.title("Average Duration by Attack Class")
plt.xlabel("Attack Class")
plt.ylabel("Average Duration")

plt.show()

# %%
categorical_cols = ["protocol_type", "service", "flag"]

train_df = pd.get_dummies(train_df, columns=categorical_cols)
test_df  = pd.get_dummies(test_df, columns=categorical_cols)

print(" Categorical Encoding Done!")
# Out:
#  Categorical Encoding Done!

# %%
train_df, test_df = train_df.align(test_df, join="left", axis=1, fill_value=0)

print(" Train & Test Columns Aligned!")
# Out:
#  Train & Test Columns Aligned!

# %%
X = train_df.drop("class", axis=1)
y = train_df["class"]

X_test = test_df.drop("class", axis=1)
y_test = test_df["class"]

print(" Features & Labels Separated!")
# Out:
#  Features & Labels Separated!

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)
X_test_scaled = scaler.transform(X_test)

print(" Data Standardized Successfully!")
# Out:
#  Data Standardized Successfully!

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    X_scaled, y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

print(" Dataset Split Completed!")
print("Training Set:", X_train.shape)
print("Validation Set:", X_val.shape)
print("Test Set:", X_test_scaled.shape)
# Out:
#  Dataset Split Completed!
# Training Set: (100778, 123)
# Validation Set: (25195, 123)
# Test Set: (22544, 123)
